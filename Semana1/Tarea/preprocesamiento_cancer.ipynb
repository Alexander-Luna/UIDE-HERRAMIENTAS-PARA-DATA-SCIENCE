# %% [markdown]
# # Librerías

# %%
########## librerías a utilizar ##########

#Se importan la librerías a utilizar
import numpy as np
import pandas as pd

# %% [markdown]
# # Importar datos

# %%
########## Importando la data ##########

#Importar los datos de los archivos .csv almacenados en PC
#df_test = pd.read_csv('titanic_test.csv')
#df_train = pd.read_csv('titanic_train.csv')

#print(df_test.head())
#print(df_train.head())

from google.colab import drive
drive.mount('/content/drive')


# Corrected URLs for raw CSV files
test_path = 'https://raw.githubusercontent.com/Alexander-Luna/UIDE-HERRAMIENTAS-PARA-DATA-SCIENCE/main/Semana1/Tarea/wdbc_test.csv'
train_path = "https://raw.githubusercontent.com/Alexander-Luna/UIDE-HERRAMIENTAS-PARA-DATA-SCIENCE/main/Semana1/Tarea/wdbc_train.csv"

# Leer el archivo CSV
df_test = pd.read_csv(test_path)
df_train = pd.read_csv(train_path)

print(df_test.head())
print(df_train.head())
# Out:
# Mounted at /content/drive
#         id diagnosis  radius1  texture1  perimeter1  area1  smoothness1  \
# 0  9112085         B   13.380     30.72       86.34  557.2      0.09245
# 1  9112366         B   11.630     29.29       74.87  415.1      0.09357
# 2  9112367         B   13.210     25.25       84.10  537.9      0.08791
# 3  9112594         B   13.000     25.13       82.61  520.2      0.08369
# 4  9112712         B    9.755     28.20       61.68  290.9      0.07984
#
#    compactness1  concavity1  concave_points1  ...  radius3  texture3  \
# 0       0.07426     0.02819          0.03264  ...    15.05     41.61
# 1       0.08574     0.07160          0.02017  ...    13.12     38.81
# 2       0.05205     0.02772          0.02068  ...    14.35     34.23
# 3       0.05073     0.01206          0.01762  ...    14.34     31.88
# 4       0.04626     0.01541          0.01043  ...    10.67     36.92
#
#    perimeter3  area3  smoothness3  compactness3  concavity3  concave_points3  \
# 0       96.69  705.6       0.1172        0.1421     0.07003          0.07763
# 1       86.04  527.8       0.1406        0.2031     0.29230          0.06835
# 2       91.29  632.9       0.1289        0.1063     0.13900          0.06005
# 3       91.06  628.5       0.1218        0.1093     0.04462          0.05921
# 4       68.03  349.9       0.1110        0.1109     0.07190          0.04866
#
#    symmetry3  fractal_dimension3
# 0     0.2196             0.07675
# 1     0.2884             0.07220
# 2     0.2444             0.06788
# 3     0.2306             0.06291
# 4     0.2321             0.07211
#
# [5 rows x 32 columns]
#          id diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0    842302         M    17.99     10.38      122.80  1001.0      0.11840
# 1    842517         M    20.57     17.77      132.90  1326.0      0.08474
# 2  84300903         M    19.69     21.25      130.00  1203.0      0.10960
# 3  84348301         M    11.42     20.38       77.58   386.1      0.14250
# 4  84358402         M    20.29     14.34      135.10  1297.0      0.10030
#
#    compactness1  concavity1  concave_points1  ...  radius3  texture3  \
# 0       0.27760      0.3001          0.14710  ...    25.38     17.33
# 1       0.07864      0.0869          0.07017  ...    24.99     23.41
# 2       0.15990      0.1974          0.12790  ...    23.57     25.53
# 3       0.28390      0.2414          0.10520  ...    14.91     26.50
# 4       0.13280      0.1980          0.10430  ...    22.54     16.67
#
#    perimeter3   area3  smoothness3  compactness3  concavity3  concave_points3  \
# 0      184.60  2019.0       0.1622        0.6656      0.7119           0.2654
# 1      158.80  1956.0       0.1238        0.1866      0.2416           0.1860
# 2      152.50  1709.0       0.1444        0.4245      0.4504           0.2430
# 3       98.87   567.7       0.2098        0.8663      0.6869           0.2575
# 4      152.20  1575.0       0.1374        0.2050      0.4000           0.1625
#
#    symmetry3  fractal_dimension3
# 0     0.4601             0.11890
# 1     0.2750             0.08902
# 2     0.3613             0.08758
# 3     0.6638             0.17300
# 4     0.2364             0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# # Entendimiento de datos

# %%
########## Entendimiento de la data ##########

#Verifica la cantidad de datos que hay en los dataset
print('Cantidad de datos:')
print(df_train.shape)
print(df_test.shape)

#Verifica el tipo de datos contenida en ambos dataset
print('Tipos de datos:')
print(df_train.info())
print(df_test.info())

#Verifica los datos faltantes de los dataset
print('Datos faltantes:')
print(pd.isnull(df_train).sum())
print(pd.isnull(df_test).sum())

#Verifica las estadísticas básicas del dataset
print('Estadísticas del dataset:')
print(df_train.describe())
print(df_test.describe())
# Out:
# Cantidad de datos:
# (455, 32)
# (114, 32)
# Tipos de datos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  455 non-null    int64
#  1   diagnosis           455 non-null    object
#  2   radius1             455 non-null    float64
#  3   texture1            455 non-null    float64
#  4   perimeter1          455 non-null    float64
#  5   area1               455 non-null    float64
#  6   smoothness1         455 non-null    float64
#  7   compactness1        455 non-null    float64
#  8   concavity1          455 non-null    float64
#  9   concave_points1     455 non-null    float64
#  10  symmetry1           455 non-null    float64
#  11  fractal_dimension1  455 non-null    float64
#  12  radius2             455 non-null    float64
#  13  texture2            455 non-null    float64
#  14  perimeter2          455 non-null    float64
#  15  area2               455 non-null    float64
#  16  smoothness2         455 non-null    float64
#  17  compactness2        455 non-null    float64
#  18  concavity2          455 non-null    float64
#  19  concave_points2     455 non-null    float64
#  20  symmetry2           455 non-null    float64
#  21  fractal_dimension2  455 non-null    float64
#  22  radius3             455 non-null    float64
#  23  texture3            455 non-null    float64
#  24  perimeter3          455 non-null    float64
#  25  area3               455 non-null    float64
#  26  smoothness3         455 non-null    float64
#  27  compactness3        455 non-null    float64
#  28  concavity3          455 non-null    float64
#  29  concave_points3     455 non-null    float64
#  30  symmetry3           455 non-null    float64
#  31  fractal_dimension3  455 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 113.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  114 non-null    int64
#  1   diagnosis           114 non-null    object
#  2   radius1             114 non-null    float64
#  3   texture1            114 non-null    float64
#  4   perimeter1          114 non-null    float64
#  5   area1               114 non-null    float64
#  6   smoothness1         114 non-null    float64
#  7   compactness1        114 non-null    float64
#  8   concavity1          114 non-null    float64
#  9   concave_points1     114 non-null    float64
#  10  symmetry1           114 non-null    float64
#  11  fractal_dimension1  114 non-null    float64
#  12  radius2             114 non-null    float64
#  13  texture2            114 non-null    float64
#  14  perimeter2          114 non-null    float64
#  15  area2               114 non-null    float64
#  16  smoothness2         114 non-null    float64
#  17  compactness2        114 non-null    float64
#  18  concavity2          114 non-null    float64
#  19  concave_points2     114 non-null    float64
#  20  symmetry2           114 non-null    float64
#  21  fractal_dimension2  114 non-null    float64
#  22  radius3             114 non-null    float64
#  23  texture3            114 non-null    float64
#  24  perimeter3          114 non-null    float64
#  25  area3               114 non-null    float64
#  26  smoothness3         114 non-null    float64
#  27  compactness3        114 non-null    float64
#  28  concavity3          114 non-null    float64
#  29  concave_points3     114 non-null    float64
#  30  symmetry3           114 non-null    float64
#  31  fractal_dimension3  114 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 28.6+ KB
# None
# Datos faltantes:
# id                    0
# diagnosis             0
# radius1               0
# texture1              0
# perimeter1            0
# area1                 0
# smoothness1           0
# compactness1          0
# concavity1            0
# concave_points1       0
# symmetry1             0
# fractal_dimension1    0
# radius2               0
# texture2              0
# perimeter2            0
# area2                 0
# smoothness2           0
# compactness2          0
# concavity2            0
# concave_points2       0
# symmetry2             0
# fractal_dimension2    0
# radius3               0
# texture3              0
# perimeter3            0
# area3                 0
# smoothness3           0
# compactness3          0
# concavity3            0
# concave_points3       0
# symmetry3             0
# fractal_dimension3    0
# dtype: int64
# id                    0
# diagnosis             0
# radius1               0
# texture1              0
# perimeter1            0
# area1                 0
# smoothness1           0
# compactness1          0
# concavity1            0
# concave_points1       0
# symmetry1             0
# fractal_dimension1    0
# radius2               0
# texture2              0
# perimeter2            0
# area2                 0
# smoothness2           0
# compactness2          0
# concavity2            0
# concave_points2       0
# symmetry2             0
# fractal_dimension2    0
# radius3               0
# texture3              0
# perimeter3            0
# area3                 0
# smoothness3           0
# compactness3          0
# concavity3            0
# concave_points3       0
# symmetry3             0
# fractal_dimension3    0
# dtype: int64
# Estadísticas del dataset:
#                  id     radius1    texture1  perimeter1        area1  \
# count  4.550000e+02  455.000000  455.000000  455.000000   455.000000
# mean   2.713560e+07   14.235347   18.989495   92.703626   663.945714
# std    1.114952e+08    3.501131    4.082756   24.121930   347.787697
# min    8.670000e+03    6.981000    9.710000   43.790000   143.500000
# 25%    8.650025e+05   11.780000   16.020000   75.485000   427.950000
# 50%    8.971370e+05   13.460000   18.660000   87.020000   559.200000
# 75%    8.813003e+06   16.130000   21.550000  106.450000   804.100000
# max    9.111573e+08   28.110000   39.280000  188.500000  2499.000000
#
#        smoothness1  compactness1  concavity1  concave_points1   symmetry1  \
# count   455.000000    455.000000  455.000000       455.000000  455.000000
# mean      0.096464      0.104998    0.091380         0.050351    0.182320
# std       0.013702      0.053867    0.080748         0.039167    0.028121
# min       0.062510      0.019380    0.000000         0.000000    0.116700
# 25%       0.086675      0.065090    0.028860         0.020365    0.162400
# 50%       0.096460      0.092420    0.066510         0.035280    0.180600
# 75%       0.105400      0.130600    0.135100         0.077415    0.196600
# max       0.144700      0.345400    0.426800         0.201200    0.304000
#
#        ...     radius3    texture3  perimeter3        area3  smoothness3  \
# count  ...  455.000000  455.000000  455.000000   455.000000   455.000000
# mean   ...   16.450044   25.411033  108.434637   898.830110     0.132548
# std    ...    4.835225    6.048317   33.481061   565.204774     0.023018
# min    ...    7.930000   12.020000   50.410000   185.200000     0.071170
# 25%    ...   13.060000   20.870000   84.470000   517.950000     0.116600
# 50%    ...   15.030000   25.200000   98.370000   698.700000     0.131500
# 75%    ...   19.515000   29.255000  128.900000  1170.000000     0.146450
# max    ...   33.130000   49.540000  229.300000  3432.000000     0.222600
#
#        compactness3  concavity3  concave_points3   symmetry3  \
# count    455.000000  455.000000       455.000000  455.000000
# mean       0.258022    0.278478         0.117214    0.294085
# std        0.162487    0.212058         0.066850    0.064486
# min        0.027290    0.000000         0.000000    0.156500
# 25%        0.147500    0.112100         0.063295    0.253150
# 50%        0.215600    0.231800         0.101700    0.284200
# 75%        0.345600    0.391600         0.171000    0.321100
# max        1.058000    1.252000         0.291000    0.663800
#
#        fractal_dimension3
# count          455.000000
# mean             0.084015
# std              0.018423
# min              0.055040
# 25%              0.071270
# 50%              0.080090
# 75%              0.092165
# max              0.207500
#
# [8 rows x 31 columns]
#                  id     radius1    texture1  perimeter1        area1  \
# count  1.140000e+02  114.000000  114.000000  114.000000   114.000000
# mean   4.328838e+07   13.696018   20.487632   89.037105   618.742105
# std    1.685541e+08    3.597365    4.919801   24.885017   367.275471
# min    9.122700e+04    7.691000   11.280000   47.920000   170.400000
# 25%    9.141598e+05   11.517500   16.710000   74.122500   403.850000
# 50%    9.213735e+05   13.150000   20.030000   84.190000   537.100000
# 75%    7.065874e+06   14.855000   24.382500   96.322500   680.850000
# max    9.113205e+08   27.420000   30.720000  186.900000  2501.000000
#
#        smoothness1  compactness1  concavity1  concave_points1   symmetry1  \
# count   114.000000    114.000000  114.000000       114.000000  114.000000
# mean      0.095948      0.101718    0.078500         0.043205    0.176539
# std       0.015484      0.048510    0.074934         0.036930    0.023947
# min       0.052630      0.033980    0.000000         0.000000    0.106000
# 25%       0.084953      0.063808    0.029773         0.019810    0.161450
# 50%       0.094305      0.093580    0.051535         0.030425    0.171850
# 75%       0.104750      0.124350    0.101750         0.053027    0.188175
# max       0.163400      0.277000    0.363500         0.168900    0.239700
#
#        ...     radius3    texture3  perimeter3        area3  smoothness3  \
# count  ...  114.000000  114.000000  114.000000   114.000000   114.000000
# mean   ...   15.547360   26.739649  102.577807   807.755263     0.131651
# std    ...    4.778344    6.440903   33.825913   582.470440     0.022163
# min    ...    8.678000   14.200000   54.490000   223.600000     0.089960
# 25%    ...   12.472500   21.935000   82.100000   475.300000     0.116750
# 50%    ...   14.475000   25.845000   95.020000   641.000000     0.129050
# 75%    ...   16.697500   31.660000  112.075000   851.825000     0.142350
# max    ...   36.040000   42.790000  251.200000  4254.000000     0.200600
#
#        compactness3  concavity3  concave_points3   symmetry3  \
# count    114.000000  114.000000       114.000000  114.000000
# mean       0.239269    0.247084         0.104198    0.274074
# std        0.134432    0.193161         0.060225    0.047000
# min        0.052130    0.000000         0.000000    0.156600
# 25%        0.146425    0.124850         0.066287    0.240625
# 50%        0.210700    0.188250         0.095835    0.268000
# 75%        0.308275    0.340050         0.135700    0.305775
# max        0.868100    1.170000         0.265000    0.467700
#
#        fractal_dimension3
# count          114.000000
# mean             0.083669
# std              0.016612
# min              0.058710
# 25%              0.072225
# 50%              0.078975
# 75%              0.091170
# max              0.140900
#
# [8 rows x 31 columns]

# %% [markdown]
# # Preprocesamiento de datos

# %%
########## Preprocesamiento de la data ##########

# Transforma los datos de la variable sexo (categórico) en números
df_train['diagnosis'].replace(['B','M'],[0,1],inplace=True)
df_test['diagnosis'].replace(['B','M'],[0,1],inplace=True)

#Crea varios grupos/rangos de edades
#Rangos de edad: 0-8, 9-15, 16-18, 19-25, 26-40, 41-60, 61-100
bins = [0, 8, 15, 18, 25, 40, 60, 100]
names = ['1', '2', '3', '4', '5', '6', '7']
df_train['Age'] = pd.cut(df_train['Age'], bins, labels = names)
df_test['Age'] = pd.cut(df_test['Age'], bins, labels = names)

#Se elimina la columna de "Cabin" ya que tiene muchos datos perdidos
# El parámetro axis=1 indica que se deben eliminar columnas en lugar de filas (axis=0).
# El parámetro inplace indica si la operación se realiza directamente en el
# DataFrame original o devolvuelve una nueva copia con filas o columnas eliminadas.
df_train.drop(['Cabin'], axis = 1, inplace=True)
df_test.drop(['Cabin'], axis = 1, inplace=True)

#Elimina las columnas que se considera que no son necesarias para el analisis
df_train = df_train.drop(['PassengerId','Name','Ticket'], axis=1)
df_test = df_test.drop(['Name','Ticket'], axis=1)

#Se elimina las filas con datos perdidos

df_train.dropna(axis=0, how='any', inplace=True)
df_test.dropna(axis=0, how='any', inplace=True)

#Verifica los datos faltantes y tamaño
print(pd.isnull(df_train).sum())
print(pd.isnull(df_test).sum())

print(df_train.shape)
print(df_test.shape)

print(df_test.head())
print(df_train.head())

# Guardar el DataFrame en un archivo CSV
df_train.to_csv('/content/drive/MyDrive/Colab Notebooks/train_procesado2.csv', index=False, sep=',', encoding='utf-8')

# %% [markdown]
# # NORMALIZACIÓN

# %%
# Las variables categóricas NO se normalizan; se codifican (One-Hot, Label Encoding, etc.)
from sklearn.preprocessing import MinMaxScaler

# Normalizar solo la columna Fare (la única numérica continua)
# Se usa fit_transform para el train y transform para test (buena práctica en ML)
scaler = MinMaxScaler(feature_range=(0,1))
df_train['Fare_normalized'] = scaler.fit_transform(df_train[['Fare']])
df_test['Fare_normalized'] = scaler.transform(df_test[['Fare']])

# reduce dimensiones (opcional)
df_train['SibSp_Parch'] = df_train['SibSp'] + df_train['Parch']

# (Opcional) Si deseas eliminar la columna Fare original y otras:
df_train.drop(columns=['Fare'], inplace=True)
df_train.drop(columns=['SibSp'], inplace=True)
df_train.drop(columns=['Parch'], inplace=True)
# df_test.drop(columns=['Fare'], inplace=True)

df_train.to_csv('train_procesado_2.csv', index=False, sep=',', encoding='utf-8')
